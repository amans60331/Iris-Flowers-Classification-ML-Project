# %% [markdown]
# # Iris Flowers Classification ML Project

# %% [markdown]
# # LetsGrowMore - Data Science Internship
# # LGMVIP - October 2021 Batch
# #  Author: AMAN SHARMA
# # BEGINNER LEVEL TASK - 01
# #

# %%
import pandas as pd
df=pd.read_csv("../input/iris/Iris.csv",encoding='unicode_escape')
df.head()

# %%
df.columns

# %%
df.info()
# The info() function here is used to display a concise summary of the DataFrame.

# %%
df.describe()  #It analyzes both numeric and object series and also the DataFrame column sets of mixed data types.

# %% [markdown]
# # DATA VISUALIZATION

# %% [markdown]
# ## Histogram using pyplot

# %%
import matplotlib.pyplot as plt   ##from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (12, 8)
plt.hist(df['SepalLengthCm'],bins= 15)
plt.xlabel("Length of Sepal")
plt.ylabel("Number of sepals")
plt.show()

# %% [markdown]
# ## Histogram using seaborn

# %%
import seaborn as sns
sns.set()
plt.hist(df['SepalLengthCm'],bins= 15)
plt.xlabel("Length of Sepal")
plt.ylabel("Number of sepals")
plt.show()

# %% [markdown]
# ### Bee swarmplot

# %%
sns.swarmplot(x='Species',y='SepalWidthCm',data=df)

# %% [markdown]
# # **Correlation heatmap**

# %%
sns.heatmap(df.corr(), annot=True, vmin=-1, vmax=1, cmap='BrBG')

# %% [markdown]
# # PAIRPLOT

# %%
sns.pairplot(df, hue='Species')

# %% [markdown]
# **Iris-setosa is very distinguishable from the others in all graphs**

# %% [markdown]
# # VIOLINPLOT

# %%
sns.violinplot(data=df)

# %% [markdown]
# # BOXPLOT

# %%
sns.boxplot(data=df)

# %% [markdown]
# **Not much outliers in the data**

# %% [markdown]
# # Joinplot

# %%
sns.jointplot(data=df, x='SepalWidthCm', y='SepalLengthCm', hue='Species')

# %% [markdown]
# ### Know the correct value of bins for your dataset
# - find number of rows
# - calculate squarerrot of num of rows
# - convert it into int

# %%
num_rows=len(df['SepalLengthCm'])
num_rows

# %%
import numpy as np
int(np.sqrt(num_rows))

# %% [markdown]
# 12 No. of BINS

# %% [markdown]
# ##  **Classification of species**

# %%
from sklearn.model_selection import train_test_split
X = df[['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
Y = df[['Species']]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size = 0.7)

# %%
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape

# %%
from sklearn.linear_model import LogisticRegression

# %%
LgR = LogisticRegression()

# %%
LgR.fit(X_train, Y_train)

# %%
Y_pred = LgR.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Y_pred, Y_test)

# %% [markdown]
# # CONCLUSION
# # # We came to the conclusion that our model is predicting the data with 100% accuracy
